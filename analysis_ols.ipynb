# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from scipy.spatial.distance import mahalanobis

import statsmodels.api as sm
from statsmodels.stats.stattools import durbin_watson
from statsmodels.stats.diagnostic import linear_reset, het_breuschpagan
from statsmodels.tools.tools import add_constant

# %% [markdown]
# # Load data

# %%
research = pd.read_csv('./research.csv')
design = pd.read_csv('./design.csv')
improvement = pd.read_csv('./improvement.csv')

# %%
survey = pd.read_csv('./survey.csv')

# %% [markdown]
# # Log analysis

# %%
def mahalanobis_distance(row, mean, inv_cov_matrix):
    diff = row - mean
    return np.sqrt(diff.T @ inv_cov_matrix @ diff)

# %%
def get_iqr_outlier_indexes(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Determine the outlier range
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Get the indexes of outliers
    outlier_indexes = df[(df[column] < lower_bound) | (df[column] > upper_bound)].index
    return outlier_indexes

# %% [markdown]
# ## Research

# %%
results_d = []
results_h3 = []
for kkk,j in enumerate(df2.columns):
    r2 = pd.DataFrame()
    r2['research_time_sum'] = research_time.sum(axis=1)
    r2['research_click_sum'] = research_click.sum(axis=1)

    # Step 1: Remove outliers from 'research_time_sum'
    idx = get_iqr_outlier_indexes(r2, 'research_time_sum')
    r3 = r2.drop(r2.index[idx]).reset_index(drop=True)  # Remove outliers and reset index
    df_filtered = df2.drop(df2.index[idx])[j].reset_index(drop=True)  # Drop corresponding outliers in df2[j]

    # Step 2: Remove outliers from 'research_click_sum' based on updated r3
    idx = get_iqr_outlier_indexes(r3, 'research_click_sum')
    r3 = r3.drop(r3.index[idx]).reset_index(drop=True)  # Drop outliers in 'research_click_sum'
    df_filtered = df_filtered.drop(df_filtered.index[idx]).reset_index(drop=True)  # Sync df_filtered with remaining indices

    # Step 3: Normalize data with MinMaxScaler and prepare for OLS model
    min_max_scaler = MinMaxScaler()
    X_MinMax_train = min_max_scaler.fit_transform(r3)
    r = pd.DataFrame(X_MinMax_train, columns=r3.columns)  # Scale r3 and ensure columns match

    # Add constant and select columns for OLS
    r = sm.add_constant(r[['research_time_sum', 'research_click_sum']])

    df3 = pd.DataFrame()
    df3[j] = df_filtered


    model_filtered = sm.OLS(df3[j], r)
    
    results = model_filtered.fit()
    results_robust = model_filtered.fit(cov_type='HC3')

    results_d.append(results)
    results_h3.append(results_robust)

    # 1. 선형성 검정 (RESET 테스트 사용)
    def linearity_test():
        reset_test = linear_reset(results_robust, power=2, test_type='fitted')
        p_value = reset_test.pvalue
        # print(f"RESET test p-value: {p_value}")
        return p_value
    
    # 2. 정규성 검정
    def normality_test():
        _, p_value = stats.normaltest(residuals)
        # print(f"Normality test p-value: {p_value}")
        return p_value
    
    # 3. 등분산성 검정
    def homoscedasticity_test():
        _, p_value, _, _ = het_breuschpagan(residuals, results_robust.model.exog)
        # print(f"Heteroscedasticity test p-value: {p_value}")
        return p_value
    
    # 4. 독립성 검정
    def independence_test():
        # dw_statistic = durbin_watson(residuals)
        dw_statistic=dg.acorr_breusch_godfrey(results_robust, nlags=3)[1]
        # dw_statistic = het_white(results_robust.resid, results_robust.model.exog)[1]
        # print(f"Durbin-Watson statistic: {dw_statistic}")
        return dw_statistic
    
    if any(ele <= 0.05 for ele in results.pvalues[1:].values):               
        residuals = results.resid
        fitted_values = results.fittedvalues    
        # 테스트 실행
        # print("1. Linearity Test")
        linearity_p_value = linearity_test()
        
        # print("\n2. Normality Test")
        normality_p_value = normality_test()
        
        # print("\n3. Homoscedasticity Test")
        homoscedasticity_p_value = homoscedasticity_test()
        
        # print("\n4. Independence Test")
        dw_statistic = independence_test()
        if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            # 결과 해석
            print("\nResults Interpretation:")
            print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
            print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
            print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
            # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
            print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
            print(j)
            print(results_robust.summary())
        
            print('========================================================================')
# Out:
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹이 디자인 업무/공부에 효과적일 수 있다고 생각하나요?
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     웹이 디자인 업무/공부에 효과적일 수 있다고 생각하나요?   R-squared:                       0.245
# Model:                                         OLS   Adj. R-squared:                  0.185
# Method:                              Least Squares   F-statistic:                     3.344
# Date:                             Tue, 12 Nov 2024   Prob (F-statistic):             0.0517
# Time:                                     15:05:16   Log-Likelihood:                -44.147
# No. Observations:                               28   AIC:                             94.29
# Df Residuals:                                   25   BIC:                             98.29
# Df Model:                                        2
# Covariance Type:                               HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  5.1998      0.530      9.810      0.000       4.161       6.239
# research_time_sum      3.6798      1.423      2.585      0.010       0.890       6.470
# research_click_sum    -3.9615      2.149     -1.844      0.065      -8.173       0.250
# ==============================================================================
# Omnibus:                        2.884   Durbin-Watson:                   1.253
# Prob(Omnibus):                  0.236   Jarque-Bera (JB):                1.559
# Skew:                          -0.518   Prob(JB):                        0.459
# Kurtosis:                       3.511   Cond. No.                         9.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹이 디자인 업무/공부를 수월하게 할 수 있다고 생각하나요?
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     웹이 디자인 업무/공부를 수월하게 할 수 있다고 생각하나요?   R-squared:                       0.193
# Model:                                           OLS   Adj. R-squared:                  0.129
# Method:                                Least Squares   F-statistic:                     2.264
# Date:                               Tue, 12 Nov 2024   Prob (F-statistic):              0.125
# Time:                                       15:05:16   Log-Likelihood:                -43.084
# No. Observations:                                 28   AIC:                             92.17
# Df Residuals:                                     25   BIC:                             96.16
# Df Model:                                          2
# Covariance Type:                                 HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  4.8890      0.476     10.260      0.000       3.955       5.823
# research_time_sum      3.2309      1.570      2.058      0.040       0.154       6.307
# research_click_sum    -2.8984      2.169     -1.336      0.182      -7.150       1.353
# ==============================================================================
# Omnibus:                        1.344   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.511   Jarque-Bera (JB):                1.010
# Skew:                          -0.455   Prob(JB):                        0.604
# Kurtosis:                       2.806   Cond. No.                         9.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹의 UI가 일관성이 있다고 생각하나요?
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     웹의 UI가 일관성이 있다고 생각하나요?   R-squared:                       0.150
# Model:                                OLS   Adj. R-squared:                  0.082
# Method:                     Least Squares   F-statistic:                     1.420
# Date:                    Tue, 12 Nov 2024   Prob (F-statistic):              0.260
# Time:                            15:05:16   Log-Likelihood:                -47.622
# No. Observations:                      28   AIC:                             101.2
# Df Residuals:                          25   BIC:                             105.2
# Df Model:                               2
# Covariance Type:                      HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  5.2007      0.634      8.202      0.000       3.958       6.443
# research_time_sum      2.6019      1.760      1.478      0.139      -0.847       6.051
# research_click_sum    -3.5298      2.111     -1.672      0.095      -7.668       0.608
# ==============================================================================
# Omnibus:                        2.029   Durbin-Watson:                   2.369
# Prob(Omnibus):                  0.363   Jarque-Bera (JB):                1.429
# Skew:                          -0.329   Prob(JB):                        0.489
# Kurtosis:                       2.110   Cond. No.                         9.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================

# %%
# VIF 계산 함수
def calculate_vif(X):
    X = add_constant(X)
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

vif = calculate_vif(r)
print("VIF 값:")
print(vif)

# VIF 기준으로 변수 선택 (예: VIF < 5)
selected_vars = vif[vif['VIF'] < 5]['variables'].tolist()
selected_vars = [var for var in selected_vars if var != 'const']
selected_vars
# Out:
# VIF 값:
#             variables       VIF
# 0               const  4.637059
# 1   research_time_sum  2.559600
# 2  research_click_sum  2.559600
# ['research_time_sum', 'research_click_sum']

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
results_d = []
results_h3 = []
for kkk,j in enumerate(df2.columns):
    d2 = pd.DataFrame()
    d2['design_time_sum'] = design_time.sum(axis=1)
    d2['design_click_sum'] = design_click.sum(axis=1)

    # Step 1: Remove outliers from 'research_time_sum'
    idx = get_iqr_outlier_indexes(d2, 'design_time_sum')
    d3 = d2.drop(d2.index[idx]).reset_index(drop=True)  # Remove outliers and reset index
    df_filtered = df2.drop(df2.index[idx])[j].reset_index(drop=True)  # Drop corresponding outliers in df2[j]

    # Step 2: Remove outliers from 'research_click_sum' based on updated r3
    idx = get_iqr_outlier_indexes(d3, 'design_click_sum')
    d3 = d3.drop(d3.index[idx]).reset_index(drop=True)  # Drop outliers in 'research_click_sum'
    df_filtered = df_filtered.drop(df_filtered.index[idx]).reset_index(drop=True)  # Sync df_filtered with remaining indices

    # Step 3: Normalize data with MinMaxScaler and prepare for OLS model
    min_max_scaler = MinMaxScaler()
    X_MinMax_train = min_max_scaler.fit_transform(d3)
    d = pd.DataFrame(X_MinMax_train, columns=d3.columns)  # Scale r3 and ensure columns match

    # Add constant and select columns for OLS
    d = sm.add_constant(d[['design_time_sum', 'design_click_sum']])

    df3 = pd.DataFrame()
    df3[j] = df_filtered


    model_filtered = sm.OLS(df3[j], d)
    
    results = model_filtered.fit()
    results_robust = model_filtered.fit(cov_type='HC3')

    results_d.append(results)
    results_h3.append(results_robust)

    # 1. 선형성 검정 (RESET 테스트 사용)
    def linearity_test():
        reset_test = linear_reset(results_robust, power=2, test_type='fitted')
        p_value = reset_test.pvalue
        # print(f"RESET test p-value: {p_value}")
        return p_value
    
    # 2. 정규성 검정
    def normality_test():
        _, p_value = stats.normaltest(residuals)
        # print(f"Normality test p-value: {p_value}")
        return p_value
    
    # 3. 등분산성 검정
    def homoscedasticity_test():
        _, p_value, _, _ = het_breuschpagan(residuals, results_robust.model.exog)
        # print(f"Heteroscedasticity test p-value: {p_value}")
        return p_value
    
    # 4. 독립성 검정
    def independence_test():
        # dw_statistic = durbin_watson(residuals)
        dw_statistic=dg.acorr_breusch_godfrey(results_robust, nlags=3)[1]
        # dw_statistic = het_white(results_robust.resid, results_robust.model.exog)[1]
        # print(f"Durbin-Watson statistic: {dw_statistic}")
        return dw_statistic
    
    if any(ele <= 0.05 for ele in results_robust.pvalues[1:].values):               
        residuals = results_robust.resid
        fitted_values = results_robust.fittedvalues    
        # 테스트 실행
        # print("1. Linearity Test")
        linearity_p_value = linearity_test()
        
        # print("\n2. Normality Test")
        normality_p_value = normality_test()
        
        # print("\n3. Homoscedasticity Test")
        homoscedasticity_p_value = homoscedasticity_test()
        
        # print("\n4. Independence Test")
        dw_statistic = independence_test()
        if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            # 결과 해석
            print("\nResults Interpretation:")
            print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
            print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
            print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
            # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
            print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
            print(j)
            print(results_robust.summary())
        
            print('========================================================================')
# Out:
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹이 디자인 업무/공부를 수행하는데 성취감을 줄 수 있다고 생각하나요?
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     웹이 디자인 업무/공부를 수행하는데 성취감을 줄 수 있다고 생각하나요?   R-squared:                       0.184
# Model:                                                 OLS   Adj. R-squared:                  0.119
# Method:                                      Least Squares   F-statistic:                     3.096
# Date:                                     Tue, 12 Nov 2024   Prob (F-statistic):             0.0629
# Time:                                             15:07:06   Log-Likelihood:                -49.908
# No. Observations:                                       28   AIC:                             105.8
# Df Residuals:                                           25   BIC:                             109.8
# Df Model:                                                2
# Covariance Type:                                       HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                5.5349      0.533     10.384      0.000       4.490       6.580
# design_time_sum     -2.6996      1.206     -2.239      0.025      -5.063      -0.336
# design_click_sum     0.6124      1.212      0.505      0.613      -1.763       2.988
# ==============================================================================
# Omnibus:                        2.754   Durbin-Watson:                   1.706
# Prob(Omnibus):                  0.252   Jarque-Bera (JB):                1.716
# Skew:                          -0.598   Prob(JB):                        0.424
# Kurtosis:                       3.206   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹을 내가 조종할 수 있다고 느꼈나요?
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     웹을 내가 조종할 수 있다고 느꼈나요?   R-squared:                       0.284
# Model:                               OLS   Adj. R-squared:                  0.226
# Method:                    Least Squares   F-statistic:                     6.945
# Date:                   Tue, 12 Nov 2024   Prob (F-statistic):            0.00399
# Time:                           15:07:06   Log-Likelihood:                -44.618
# No. Observations:                     28   AIC:                             95.24
# Df Residuals:                         25   BIC:                             99.23
# Df Model:                              2
# Covariance Type:                     HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                5.3203      0.598      8.897      0.000       4.148       6.492
# design_time_sum     -2.8905      0.829     -3.487      0.000      -4.515      -1.266
# design_click_sum     2.1369      1.020      2.095      0.036       0.138       4.136
# ==============================================================================
# Omnibus:                        2.378   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.443
# Skew:                          -0.276   Prob(JB):                        0.486
# Kurtosis:                       2.035   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹의 결과가 정확하다고 느끼시나요?
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     웹의 결과가 정확하다고 느끼시나요?   R-squared:                       0.217
# Model:                             OLS   Adj. R-squared:                  0.154
# Method:                  Least Squares   F-statistic:                     3.715
# Date:                 Tue, 12 Nov 2024   Prob (F-statistic):             0.0387
# Time:                         15:07:06   Log-Likelihood:                -48.026
# No. Observations:                   28   AIC:                             102.1
# Df Residuals:                       25   BIC:                             106.0
# Df Model:                            2
# Covariance Type:                   HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                4.8965      0.595      8.228      0.000       3.730       6.063
# design_time_sum     -2.8191      1.093     -2.579      0.010      -4.961      -0.677
# design_click_sum     0.8165      1.312      0.622      0.534      -1.755       3.388
# ==============================================================================
# Omnibus:                        4.615   Durbin-Watson:                   1.465
# Prob(Omnibus):                  0.099   Jarque-Bera (JB):                2.093
# Skew:                          -0.352   Prob(JB):                        0.351
# Kurtosis:                       1.861   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 결과에 나의 개입이 잘 반영이 되었다고 느끼나요?
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     결과에 나의 개입이 잘 반영이 되었다고 느끼나요?   R-squared:                       0.374
# Model:                                     OLS   Adj. R-squared:                  0.324
# Method:                          Least Squares   F-statistic:                     7.334
# Date:                         Tue, 12 Nov 2024   Prob (F-statistic):            0.00312
# Time:                                 15:07:06   Log-Likelihood:                -45.615
# No. Observations:                           28   AIC:                             97.23
# Df Residuals:                               25   BIC:                             101.2
# Df Model:                                    2
# Covariance Type:                           HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                4.6952      0.496      9.467      0.000       3.723       5.667
# design_time_sum     -3.2795      0.977     -3.357      0.001      -5.194      -1.365
# design_click_sum     3.5932      1.066      3.371      0.001       1.504       5.683
# ==============================================================================
# Omnibus:                        4.748   Durbin-Watson:                   2.472
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                3.081
# Skew:                          -0.745   Prob(JB):                        0.214
# Kurtosis:                       3.650   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹이 트렌드를 분석 및 파악하는데 도움이 된다고 생각하나요?
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     웹이 트렌드를 분석 및 파악하는데 도움이 된다고 생각하나요?   R-squared:                       0.150
# Model:                                           OLS   Adj. R-squared:                  0.082
# Method:                                Least Squares   F-statistic:                     2.364
# Date:                               Tue, 12 Nov 2024   Prob (F-statistic):              0.115
# Time:                                       15:07:06   Log-Likelihood:                -52.480
# No. Observations:                                 28   AIC:                             111.0
# Df Residuals:                                     25   BIC:                             115.0
# Df Model:                                          2
# Covariance Type:                                 HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                5.4949      0.981      5.599      0.000       3.572       7.418
# design_time_sum     -2.6143      1.210     -2.160      0.031      -4.986      -0.242
# design_click_sum     1.5941      2.127      0.749      0.454      -2.576       5.764
# ==============================================================================
# Omnibus:                        3.764   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.152   Jarque-Bera (JB):                2.592
# Skew:                          -0.574   Prob(JB):                        0.274
# Kurtosis:                       2.048   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================

# %%
# VIF 계산 함수
def calculate_vif(X):
    X = add_constant(X)
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

vif = calculate_vif(research)
print("VIF 값:")
print(vif)

# VIF 기준으로 변수 선택 (예: VIF < 5)
selected_vars = vif[vif['VIF'] < 5]['variables'].tolist()
selected_vars = [var for var in selected_vars if var != 'const']
selected_vars
# Out:
# VIF 값:
#                        variables        VIF
# 0                          const  12.246960
# 1          cat_attr_mission_time   2.232852
# 2           cluster_mission_time   7.404230
# 3            naming_mission_time   1.194162
# 4  final_catattr_mission_clicked   2.119388
# 5  final_cluster_mission_clicked  10.573838
# 6   final_naming_mission_clicked   3.188962
# ['cat_attr_mission_time',
#  'naming_mission_time',
#  'final_catattr_mission_clicked',
#  'final_naming_mission_clicked']

# %%
results_d = []
results_h3 = []
for kkk,j in enumerate(df2.columns):
    i2 = pd.DataFrame()
    i2['improvement_time_sum'] = improvement_time.sum(axis=1)
    i2['improvement_click_sum'] = improvement_click.sum(axis=1)

    # Step 1: Remove outliers from 'research_time_sum'
    idx = get_iqr_outlier_indexes(i2, 'improvement_time_sum')
    i3 = i2.drop(i2.index[idx]).reset_index(drop=True)  # Remove outliers and reset index
    df_filtered = df2.drop(df2.index[idx])[j].reset_index(drop=True)  # Drop corresponding outliers in df2[j]

    # Step 2: Remove outliers from 'research_click_sum' based on updated r3
    idx = get_iqr_outlier_indexes(i3, 'improvement_click_sum')
    i3 = i3.drop(i3.index[idx]).reset_index(drop=True)  # Drop outliers in 'research_click_sum'
    df_filtered = df_filtered.drop(df_filtered.index[idx]).reset_index(drop=True)  # Sync df_filtered with remaining indices

    # Step 3: Normalize data with MinMaxScaler and prepare for OLS model
    min_max_scaler = MinMaxScaler()
    X_MinMax_train = min_max_scaler.fit_transform(i3)
    i = pd.DataFrame(X_MinMax_train, columns=i3.columns)  # Scale r3 and ensure columns match

    # Add constant and select columns for OLS
    i = sm.add_constant(i[['improvement_time_sum', 'improvement_click_sum']])

    df3 = pd.DataFrame()
    df3[j] = df_filtered


    model_filtered = sm.OLS(df3[j], i)
    
    results = model_filtered.fit()
    results_robust = model_filtered.fit(cov_type='HC3')

    results_d.append(results)
    results_h3.append(results_robust)

    # 1. 선형성 검정 (RESET 테스트 사용)
    def linearity_test():
        reset_test = linear_reset(results_robust, power=2, test_type='fitted')
        p_value = reset_test.pvalue
        # print(f"RESET test p-value: {p_value}")
        return p_value
    
    # 2. 정규성 검정
    def normality_test():
        _, p_value = stats.normaltest(residuals)
        # print(f"Normality test p-value: {p_value}")
        return p_value
    
    # 3. 등분산성 검정
    def homoscedasticity_test():
        _, p_value, _, _ = het_breuschpagan(residuals, results_robust.model.exog)
        # print(f"Heteroscedasticity test p-value: {p_value}")
        return p_value
    
    # 4. 독립성 검정
    def independence_test():
        # dw_statistic = durbin_watson(residuals)
        dw_statistic=dg.acorr_breusch_godfrey(results_robust, nlags=3)[1]
        # dw_statistic = het_white(results_robust.resid, results_robust.model.exog)[1]
        # print(f"Durbin-Watson statistic: {dw_statistic}")
        return dw_statistic
    
    if any(ele <= 0.05 for ele in results.pvalues[1:].values):               
        residuals = results.resid
        fitted_values = results.fittedvalues    
        # 테스트 실행
        # print("1. Linearity Test")
        linearity_p_value = linearity_test()
        
        # print("\n2. Normality Test")
        normality_p_value = normality_test()
        
        # print("\n3. Homoscedasticity Test")
        homoscedasticity_p_value = homoscedasticity_test()
        
        # print("\n4. Independence Test")
        dw_statistic = independence_test()
        if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            # 결과 해석
            print("\nResults Interpretation:")
            print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
            print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
            print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
            # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
            print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
            print(j)
            print(results.summary())
        
            print('========================================================================')

# %%
# VIF 계산 함수
def calculate_vif(X):
    X = add_constant(X)
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

vif = calculate_vif(r)
print("VIF 값:")
print(vif)

# VIF 기준으로 변수 선택 (예: VIF < 5)
selected_vars = vif[vif['VIF'] < 5]['variables'].tolist()
selected_vars = [var for var in selected_vars if var != 'const']
selected_vars
# Out:
# VIF 값:
#             variables       VIF
# 0               const  4.637059
# 1   research_time_sum  2.559600
# 2  research_click_sum  2.559600
# ['research_time_sum', 'research_click_sum']

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

results_d = []
results_h3 = []
for kkk,j in enumerate(df2.columns):
    i2 = pd.DataFrame()
    i2['research_time_sum'] = research_time.sum(axis=1)
    i2['research_click_sum'] = research_click.sum(axis=1)

    scaler = StandardScaler()
    X_standard_scaler = scaler.fit_transform(i2)
    i2 = pd.DataFrame(X_standard_scaler, columns=i2.columns)
    min_max_scaler = MinMaxScaler()
    X_MinMax_train = min_max_scaler.fit_transform(i2)
    i2 = pd.DataFrame(X_MinMax_train, columns=i2.columns)  # Scale r3 and ensure columns match
    i3 = sm.add_constant(i2[['research_time_sum', 'research_click_sum']])
    model_filtered = sm.OLS(df2[j], i3)
    results = model_filtered.fit()
    results_robust = model_filtered.fit(cov_type='HC3')


    # # IQR
    # idx = get_iqr_outlier_indexes(i2, 'improvement_time_sum')
    # i3 = i2.drop(i2.index[idx]).reset_index(drop=True)  # Remove outliers and reset index
    # df_filtered = df2.drop(df2.index[idx])[j].reset_index(drop=True)  # Drop corresponding outliers in df2[j]
    # idx = get_iqr_outlier_indexes(i3, 'improvement_click_sum')
    # i3 = i3.drop(i3.index[idx]).reset_index(drop=True)  # Drop outliers in 'research_click_sum'
    # df_filtered = df_filtered.drop(df_filtered.index[idx]).reset_index(drop=True)  # Sync df_filtered with remaining indices
    # min_max_scaler = MinMaxScaler()
    # X_MinMax_train = min_max_scaler.fit_transform(i3)
    # i = pd.DataFrame(X_MinMax_train, columns=i3.columns)  # Scale r3 and ensure columns match
    # i = sm.add_constant(i[['improvement_time_sum', 'improvement_click_sum']])
    # df3 = pd.DataFrame()
    # df3[j] = df_filtered
    # model_filtered = sm.OLS(df3[j], i)
    # results = model_filtered.fit()
    # results_robust = model_filtered.fit(cov_type='HC2')
    # results_d.append(results)
    # results_h3.append(results_robust)


    # 1. 선형성 검정 (RESET 테스트 사용)
    def linearity_test(res):
        reset_test = linear_reset(res, power=2, test_type='fitted')
        p_value = reset_test.pvalue
        # print(f"RESET test p-value: {p_value}")
        return p_value
    
    # 2. 정규성 검정
    def normality_test(residuals):
        _, p_value = stats.normaltest(residuals)
        # print(f"Normality test p-value: {p_value}")
        return p_value
    
    # 3. 등분산성 검정
    def homoscedasticity_test(res, residuals):
        _, p_value, _, _ = het_breuschpagan(residuals, res.model.exog)
        # print(f"Heteroscedasticity test p-value: {p_value}")
        return p_value
    
    # 4. 독립성 검정
    def independence_test(res):
        # dw_statistic = durbin_watson(residuals)
        dw_statistic=dg.acorr_breusch_godfrey(res, nlags=3)[1]
        # dw_statistic = het_white(results_robust.resid, results_robust.model.exog)[1]
        # print(f"Durbin-Watson statistic: {dw_statistic}")
        return dw_statistic

    
    if any(ele <= 0.05 for ele in results_robust.pvalues[1:].values):      
        print(j)
        print('RESULT_ROBUST')
        
        residuals = results_robust.resid
        fitted_values = results_robust.fittedvalues    
        linearity_p_value = linearity_test(results_robust)
        normality_p_value = normality_test(residuals)
        homoscedasticity_p_value = homoscedasticity_test(results_robust, residuals)
        dw_statistic = independence_test(results_robust)
        
        if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            # 결과 해석
            print("\nResults Interpretation:")
            print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
            print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
            print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
            # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
            print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
            print(j)
            print(results_robust.summary())
        
            print('========================================================================')

    # if any(ele <= 0.05 for ele in results.pvalues[1:].values):      
    #     print('RESULT', j)
        
    #     residuals = results_robust.resid
    #     fitted_values = results.fittedvalues    
    #     linearity_p_value = linearity_test(results)
    #     normality_p_value = normality_test(residuals)
    #     homoscedasticity_p_value = homoscedasticity_test(results, residuals)
    #     dw_statistic = independence_test(results)
    #     if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            
    #         # 결과 해석
    #         print("\nResults Interpretation:")
    #         print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
    #         print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
    #         print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
    #         # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
    #         print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
    #         print(results.summary())
        
    #         print('========================================================================')
# Out:
# 웹이 친절하다고 생각하나요?
# RESULT_ROBUST
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹이 친절하다고 생각하나요?
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        웹이 친절하다고 생각하나요?   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     2.897
# Date:                Tue, 12 Nov 2024   Prob (F-statistic):             0.0725
# Time:                        16:44:49   Log-Likelihood:                -49.659
# No. Observations:                  30   AIC:                             105.3
# Df Residuals:                      27   BIC:                             109.5
# Df Model:                           2
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  5.0639      0.568      8.918      0.000       3.951       6.177
# research_time_sum     -2.5299      1.227     -2.061      0.039      -4.935      -0.124
# research_click_sum     2.4259      1.123      2.160      0.031       0.225       4.627
# ==============================================================================
# Omnibus:                        0.402   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.818   Jarque-Bera (JB):                0.427
# Skew:                          -0.244   Prob(JB):                        0.808
# Kurtosis:                       2.678   Cond. No.                         8.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# ========================================================================
# stress
# RESULT_ROBUST

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

results_d = []
results_h3 = []
for kkk,j in enumerate(df2.columns):
    i2 = pd.DataFrame()
    i2['design_time_sum'] = design_time.sum(axis=1)
    i2['design_click_sum'] = design_click.sum(axis=1)

    # # scaler = StandardScaler()
    X_standard_scaler = scaler.fit_transform(i2)
    i2 = pd.DataFrame(X_standard_scaler, columns=i2.columns)
    min_max_scaler = MinMaxScaler()
    X_MinMax_train = min_max_scaler.fit_transform(i2)
    i2 = pd.DataFrame(X_MinMax_train, columns=i2.columns)  # Scale r3 and ensure columns match
    i3 = sm.add_constant(i2[['design_time_sum', 'design_click_sum']])
    model_filtered = sm.OLS(df2[j], i3)
    results = model_filtered.fit()
    results_robust = model_filtered.fit(cov_type='HC2')


    # # IQR
    # idx = get_iqr_outlier_indexes(i2, 'improvement_time_sum')
    # i3 = i2.drop(i2.index[idx]).reset_index(drop=True)  # Remove outliers and reset index
    # df_filtered = df2.drop(df2.index[idx])[j].reset_index(drop=True)  # Drop corresponding outliers in df2[j]
    # idx = get_iqr_outlier_indexes(i3, 'improvement_click_sum')
    # i3 = i3.drop(i3.index[idx]).reset_index(drop=True)  # Drop outliers in 'research_click_sum'
    # df_filtered = df_filtered.drop(df_filtered.index[idx]).reset_index(drop=True)  # Sync df_filtered with remaining indices
    # min_max_scaler = MinMaxScaler()
    # X_MinMax_train = min_max_scaler.fit_transform(i3)
    # i = pd.DataFrame(X_MinMax_train, columns=i3.columns)  # Scale r3 and ensure columns match
    # i = sm.add_constant(i[['improvement_time_sum', 'improvement_click_sum']])
    # df3 = pd.DataFrame()
    # df3[j] = df_filtered
    # model_filtered = sm.OLS(df3[j], i)
    # results = model_filtered.fit()
    # results_robust = model_filtered.fit(cov_type='HC2')
    # results_d.append(results)
    # results_h3.append(results_robust)


    # 1. 선형성 검정 (RESET 테스트 사용)
    def linearity_test(res):
        reset_test = linear_reset(res, power=2, test_type='fitted')
        p_value = reset_test.pvalue
        # print(f"RESET test p-value: {p_value}")
        return p_value
    
    # 2. 정규성 검정
    def normality_test(residuals):
        _, p_value = stats.normaltest(residuals)
        # print(f"Normality test p-value: {p_value}")
        return p_value
    
    # 3. 등분산성 검정
    def homoscedasticity_test(res, residuals):
        _, p_value, _, _ = het_breuschpagan(residuals, res.model.exog)
        # print(f"Heteroscedasticity test p-value: {p_value}")
        return p_value
    
    # 4. 독립성 검정
    def independence_test(res):
        # dw_statistic = durbin_watson(residuals)
        dw_statistic=dg.acorr_breusch_godfrey(res, nlags=3)[1]
        # dw_statistic = het_white(results_robust.resid, results_robust.model.exog)[1]
        # print(f"Durbin-Watson statistic: {dw_statistic}")
        return dw_statistic

    
    if any(ele <= 0.05 for ele in results_robust.pvalues[1:].values):      
        print(j)
        print('RESULT_ROBUST')
        
        residuals = results_robust.resid
        fitted_values = results_robust.fittedvalues    
        linearity_p_value = linearity_test(results_robust)
        normality_p_value = normality_test(residuals)
        homoscedasticity_p_value = homoscedasticity_test(results_robust, residuals)
        dw_statistic = independence_test(results_robust)
        
        if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            # 결과 해석
            print("\nResults Interpretation:")
            print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
            print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
            print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
            # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
            print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
            print(j)
            print(results_robust.summary())
        
            print('========================================================================')

    # if any(ele <= 0.05 for ele in results.pvalues[1:].values):      
    #     print('RESULT', j)
        
    #     residuals = results_robust.resid
    #     fitted_values = results.fittedvalues    
    #     linearity_p_value = linearity_test(results)
    #     normality_p_value = normality_test(residuals)
    #     homoscedasticity_p_value = homoscedasticity_test(results, residuals)
    #     dw_statistic = independence_test(results)
    #     if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            
    #         # 결과 해석
    #         print("\nResults Interpretation:")
    #         print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
    #         print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
    #         print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
    #         # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
    #         print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
    #         print(results.summary())
        
    #         print('========================================================================')
# Out:
# 웹이 디자인 업무/공부를 수월하게 할 수 있다고 생각하나요?
# RESULT_ROBUST
# 웹이 디자인 업무/공부를 수행하는데 성취감을 줄 수 있다고 생각하나요?
# RESULT_ROBUST
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹이 디자인 업무/공부를 수행하는데 성취감을 줄 수 있다고 생각하나요?
#                                        OLS Regression Results
# ===================================================================================================
# Dep. Variable:     웹이 디자인 업무/공부를 수행하는데 성취감을 줄 수 있다고 생각하나요?   R-squared:                       0.146
# Model:                                                 OLS   Adj. R-squared:                  0.083
# Method:                                      Least Squares   F-statistic:                     2.707
# Date:                                     Tue, 12 Nov 2024   Prob (F-statistic):             0.0848
# Time:                                             16:12:48   Log-Likelihood:                -53.629
# No. Observations:                                       30   AIC:                             113.3
# Df Residuals:                                           27   BIC:                             117.5
# Df Model:                                                2
# Covariance Type:                                       HC2
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                5.4545      0.534     10.223      0.000       4.409       6.500
# design_time_sum     -2.3408      1.116     -2.097      0.036      -4.528      -0.153
# design_click_sum     0.5235      1.428      0.367      0.714      -2.275       3.322
# ==============================================================================
# Omnibus:                        2.041   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.360   Jarque-Bera (JB):                1.482
# Skew:                          -0.543   Prob(JB):                        0.477
# Kurtosis:                       2.920   Cond. No.                         6.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC2)
# ========================================================================
# 웹이 주는 결과를 이해하였나요?
# RESULT_ROBUST
# 웹을 내가 조종할 수 있다고 느꼈나요?
# RESULT_ROBUST
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹을 내가 조종할 수 있다고 느꼈나요?
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     웹을 내가 조종할 수 있다고 느꼈나요?   R-squared:                       0.261
# Model:                               OLS   Adj. R-squared:                  0.206
# Method:                    Least Squares   F-statistic:                     6.329
# Date:                   Tue, 12 Nov 2024   Prob (F-statistic):            0.00557
# Time:                           16:12:48   Log-Likelihood:                -47.587
# No. Observations:                     30   AIC:                             101.2
# Df Residuals:                         27   BIC:                             105.4
# Df Model:                              2
# Covariance Type:                     HC2
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                5.3279      0.488     10.911      0.000       4.371       6.285
# design_time_sum     -2.6412      0.794     -3.326      0.001      -4.198      -1.085
# design_click_sum     2.5354      1.001      2.534      0.011       0.574       4.496
# ==============================================================================
# Omnibus:                        3.522   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.172   Jarque-Bera (JB):                1.713
# Skew:                          -0.251   Prob(JB):                        0.425
# Kurtosis:                       1.943   Cond. No.                         6.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC2)
# ========================================================================
# 웹의 결과가 정확하다고 느끼시나요?
# RESULT_ROBUST
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹의 결과가 정확하다고 느끼시나요?
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     웹의 결과가 정확하다고 느끼시나요?   R-squared:                       0.193
# Model:                             OLS   Adj. R-squared:                  0.133
# Method:                  Least Squares   F-statistic:                     3.708
# Date:                 Tue, 12 Nov 2024   Prob (F-statistic):             0.0378
# Time:                         16:12:48   Log-Likelihood:                -51.155
# No. Observations:                   30   AIC:                             108.3
# Df Residuals:                       27   BIC:                             112.5
# Df Model:                            2
# Covariance Type:                   HC2
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                4.6647      0.537      8.679      0.000       3.611       5.718
# design_time_sum     -2.6192      0.965     -2.714      0.007      -4.510      -0.728
# design_click_sum     1.6448      1.157      1.422      0.155      -0.623       3.912
# ==============================================================================
# Omnibus:                        4.668   Durbin-Watson:                   1.414
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                2.188
# Skew:                          -0.360   Prob(JB):                        0.335
# Kurtosis:                       1.890   Cond. No.                         6.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC2)
# ========================================================================
# 결과에 나의 개입이 잘 반영이 되었다고 느끼나요?
# RESULT_ROBUST
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 결과에 나의 개입이 잘 반영이 되었다고 느끼나요?
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     결과에 나의 개입이 잘 반영이 되었다고 느끼나요?   R-squared:                       0.177
# Model:                                     OLS   Adj. R-squared:                  0.116
# Method:                          Least Squares   F-statistic:                     3.002
# Date:                         Tue, 12 Nov 2024   Prob (F-statistic):             0.0665
# Time:                                 16:12:48   Log-Likelihood:                -53.430
# No. Observations:                           30   AIC:                             112.9
# Df Residuals:                               27   BIC:                             117.1
# Df Model:                                    2
# Covariance Type:                           HC2
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                5.2328      0.496     10.560      0.000       4.262       6.204
# design_time_sum     -2.6439      1.170     -2.260      0.024      -4.937      -0.351
# design_click_sum     1.9589      2.112      0.928      0.354      -2.180       6.098
# ==============================================================================
# Omnibus:                        3.502   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.174   Jarque-Bera (JB):                2.729
# Skew:                          -0.738   Prob(JB):                        0.256
# Kurtosis:                       2.957   Cond. No.                         6.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC2)
# ========================================================================
# 웹이 트렌드를 분석 및 파악하는데 도움이 된다고 생각하나요?
# RESULT_ROBUST
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹이 트렌드를 분석 및 파악하는데 도움이 된다고 생각하나요?
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     웹이 트렌드를 분석 및 파악하는데 도움이 된다고 생각하나요?   R-squared:                       0.138
# Model:                                           OLS   Adj. R-squared:                  0.074
# Method:                                Least Squares   F-statistic:                     2.853
# Date:                               Tue, 12 Nov 2024   Prob (F-statistic):             0.0752
# Time:                                       16:12:48   Log-Likelihood:                -55.595
# No. Observations:                                 30   AIC:                             117.2
# Df Residuals:                                     27   BIC:                             121.4
# Df Model:                                          2
# Covariance Type:                                 HC2
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                5.4348      0.667      8.152      0.000       4.128       6.742
# design_time_sum     -2.3904      1.067     -2.239      0.025      -4.482      -0.298
# design_click_sum     2.0654      1.359      1.520      0.129      -0.598       4.729
# ==============================================================================
# Omnibus:                        3.945   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.139   Jarque-Bera (JB):                2.686
# Skew:                          -0.559   Prob(JB):                        0.261
# Kurtosis:                       2.053   Cond. No.                         6.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC2)
# ========================================================================
# 웹이 아이디어를 탐색하는 단계에서 영감을 준다고 생각하나요?
# RESULT_ROBUST
# 웹이 디자인을 할때 보조 역할을 해줄 수 있을 것이라 생각하나요?
# RESULT_ROBUST

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

results_d = []
results_h3 = []
for kkk,j in enumerate(df2.columns):
    i2 = pd.DataFrame()
    i2['improvement_time_sum'] = improvement_time.sum(axis=1)
    i2['improvement_click_sum'] = improvement_click.sum(axis=1)

    # # scaler = StandardScaler()
    X_standard_scaler = scaler.fit_transform(i2)
    i2 = pd.DataFrame(X_standard_scaler, columns=i2.columns)
    min_max_scaler = MinMaxScaler()
    X_MinMax_train = min_max_scaler.fit_transform(i2)
    i2 = pd.DataFrame(X_MinMax_train, columns=i2.columns)  # Scale r3 and ensure columns match
    i3 = sm.add_constant(i2[['improvement_time_sum', 'improvement_click_sum']])
    model_filtered = sm.OLS(df2[j], i3)
    results = model_filtered.fit()
    results_robust = model_filtered.fit(cov_type='HC2')


    # # IQR
    # idx = get_iqr_outlier_indexes(i2, 'improvement_time_sum')
    # i3 = i2.drop(i2.index[idx]).reset_index(drop=True)  # Remove outliers and reset index
    # df_filtered = df2.drop(df2.index[idx])[j].reset_index(drop=True)  # Drop corresponding outliers in df2[j]
    # idx = get_iqr_outlier_indexes(i3, 'improvement_click_sum')
    # i3 = i3.drop(i3.index[idx]).reset_index(drop=True)  # Drop outliers in 'research_click_sum'
    # df_filtered = df_filtered.drop(df_filtered.index[idx]).reset_index(drop=True)  # Sync df_filtered with remaining indices
    # min_max_scaler = MinMaxScaler()
    # X_MinMax_train = min_max_scaler.fit_transform(i3)
    # i = pd.DataFrame(X_MinMax_train, columns=i3.columns)  # Scale r3 and ensure columns match
    # i = sm.add_constant(i[['improvement_time_sum', 'improvement_click_sum']])
    # df3 = pd.DataFrame()
    # df3[j] = df_filtered
    # model_filtered = sm.OLS(df3[j], i)
    # results = model_filtered.fit()
    # results_robust = model_filtered.fit(cov_type='HC2')
    # results_d.append(results)
    # results_h3.append(results_robust)


    # 1. 선형성 검정 (RESET 테스트 사용)
    def linearity_test(res):
        reset_test = linear_reset(res, power=2, test_type='fitted')
        p_value = reset_test.pvalue
        # print(f"RESET test p-value: {p_value}")
        return p_value
    
    # 2. 정규성 검정
    def normality_test(residuals):
        _, p_value = stats.normaltest(residuals)
        # print(f"Normality test p-value: {p_value}")
        return p_value
    
    # 3. 등분산성 검정
    def homoscedasticity_test(res, residuals):
        _, p_value, _, _ = het_breuschpagan(residuals, res.model.exog)
        # print(f"Heteroscedasticity test p-value: {p_value}")
        return p_value
    
    # 4. 독립성 검정
    def independence_test(res):
        # dw_statistic = durbin_watson(residuals)
        dw_statistic=dg.acorr_breusch_godfrey(res, nlags=3)[1]
        # dw_statistic = het_white(results_robust.resid, results_robust.model.exog)[1]
        # print(f"Durbin-Watson statistic: {dw_statistic}")
        return dw_statistic

    
    if any(ele <= 0.05 for ele in results_robust.pvalues[1:].values):      
        print(j)
        print('RESULT_ROBUST')
        
        residuals = results_robust.resid
        fitted_values = results_robust.fittedvalues    
        linearity_p_value = linearity_test(results_robust)
        normality_p_value = normality_test(residuals)
        homoscedasticity_p_value = homoscedasticity_test(results_robust, residuals)
        dw_statistic = independence_test(results_robust)
        
        if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            # 결과 해석
            print("\nResults Interpretation:")
            print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
            print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
            print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
            # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
            print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
            print(j)
            print(results_robust.summary())
        
            print('========================================================================')

    # if any(ele <= 0.05 for ele in results.pvalues[1:].values):      
    #     print('RESULT', j)
        
    #     residuals = results_robust.resid
    #     fitted_values = results.fittedvalues    
    #     linearity_p_value = linearity_test(results)
    #     normality_p_value = normality_test(residuals)
    #     homoscedasticity_p_value = homoscedasticity_test(results, residuals)
    #     dw_statistic = independence_test(results)
    #     if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            
    #         # 결과 해석
    #         print("\nResults Interpretation:")
    #         print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
    #         print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
    #         print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
    #         # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
    #         print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
    #         print(results.summary())
        
    #         print('========================================================================')
# Out:
# 웹이 디자인 업무/공부를 진행함에 만족감을 줄 수 있다고 생각하나요?
# RESULT_ROBUST
# 웹이 주는 결과를 이해하였나요?
# RESULT_ROBUST
# 웹이 창의력을 필요로 하는 업무/공부에 도움이 된다고 생각하나요?
# RESULT_ROBUST
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# 웹이 창의력을 필요로 하는 업무/공부에 도움이 된다고 생각하나요?
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     웹이 창의력을 필요로 하는 업무/공부에 도움이 된다고 생각하나요?   R-squared:                       0.089
# Model:                                              OLS   Adj. R-squared:                  0.022
# Method:                                   Least Squares   F-statistic:                     2.411
# Date:                                  Tue, 12 Nov 2024   Prob (F-statistic):              0.109
# Time:                                          16:12:57   Log-Likelihood:                -53.413
# No. Observations:                                    30   AIC:                             112.8
# Df Residuals:                                        27   BIC:                             117.0
# Df Model:                                             2
# Covariance Type:                                    HC2
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     4.7066      0.454     10.367      0.000       3.817       5.596
# improvement_time_sum     -1.1954      1.217     -0.982      0.326      -3.580       1.189
# improvement_click_sum     2.2393      1.089      2.056      0.040       0.105       4.374
# ==============================================================================
# Omnibus:                        5.297   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.071   Jarque-Bera (JB):                3.905
# Skew:                          -0.862   Prob(JB):                        0.142
# Kurtosis:                       3.392   Cond. No.                         8.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC2)
# ========================================================================

# %% [markdown]
# ## Research

# %%
# from statsmodels.stats import linear_reset, het_breuschpagan, durbin_watson
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd

results_i = []
results_h3 = []

research

for kkk, j in enumerate(survey.columns):

    # Outlier Removal using Mahalanobis Distance
    data_mean = np.mean(research, axis=0)
    cov_matrix = np.cov(research.values.T)
    inv_cov_matrix = np.linalg.inv(cov_matrix)
    mahal_distances = research.apply(mahalanobis_distance, axis=1, args=(data_mean, inv_cov_matrix))
    threshold = np.percentile(mahal_distances, 97.5)
    research_filtered = research[mahal_distances < threshold]
    survey_tmp = pd.DataFrame(survey[j][research_filtered.index]).dropna()

    # Normalize Data
    min_max_scaler = MinMaxScaler()
    research_scaled = min_max_scaler.fit_transform(research_filtered)
    research_scaled = pd.DataFrame(research_scaled, columns=research_filtered.columns)
    survey_tmp_scaled = min_max_scaler.fit_transform(survey_tmp)

    # Model Fitting
    research_scaled = sm.add_constant(research_scaled[['research_time_sum', 'research_click_sum']])
    model_filtered = sm.OLS(survey_tmp_scaled, research_scaled)
    results_robust = model_filtered.fit(cov_type='HC3')

    # Append Results
    results_h3.append(results_robust)

    # Statistical Tests
    residuals = results_robust.resid
    def linearity_test():
        reset_test = linear_reset(results_robust, power=2, test_type='fitted')
        return reset_test.pvalue

    def normality_test():
        _, p_value = stats.normaltest(residuals)
        return p_value

    def homoscedasticity_test():
        _, p_value, _, _ = het_breuschpagan(residuals, results_robust.model.exog)
        return p_value

    def independence_test():
        return durbin_watson(residuals)

    # Filter based on p-values
    linearity_p_value = linearity_test()
    normality_p_value = normality_test()
    homoscedasticity_p_value = homoscedasticity_test()
    independence_statistic = independence_test()

    # Interpretation of Results
    if (
        linearity_p_value > 0.05 and
        normality_p_value > 0.05 and
        homoscedasticity_p_value > 0.05 and
        independence_statistic > 0.05
    ):
        print(f"Column: {j}")   
        print("\nInterpretation:")
        print("Linearity: Satisfied")
        print("Normality: Satisfied")
        print("Homoscedasticity: Satisfied")
        print("Independence: Satisfied")
        print("=" * 80)
        print(results_robust.summary())
# Out:
# Column: Ease
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.201
# Model:                            OLS   Adj. R-squared:                  0.140
# Method:                 Least Squares   F-statistic:                     2.669
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):             0.0883
# Time:                        15:54:37   Log-Likelihood:                 2.5597
# No. Observations:                  29   AIC:                            0.8806
# Df Residuals:                      26   BIC:                             4.982
# Df Model:                           2
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.5777      0.080      7.219      0.000       0.421       0.735
# research_time_sum      0.7518      0.362      2.077      0.038       0.042       1.461
# research_click_sum    -0.5796      0.421     -1.376      0.169      -1.405       0.246
# ==============================================================================
# Omnibus:                        1.515   Durbin-Watson:                   1.374
# Prob(Omnibus):                  0.469   Jarque-Bera (JB):                1.050
# Skew:                          -0.464   Prob(JB):                        0.592
# Kurtosis:                       2.907   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Effectiveness
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     3.600
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):             0.0417
# Time:                        15:54:37   Log-Likelihood:                 1.4532
# No. Observations:                  29   AIC:                             3.094
# Df Residuals:                      26   BIC:                             7.195
# Df Model:                           2
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.6365      0.088      7.270      0.000       0.465       0.808
# research_time_sum      0.8644      0.329      2.626      0.009       0.219       1.509
# research_click_sum    -0.7905      0.411     -1.922      0.055      -1.597       0.016
# ==============================================================================
# Omnibus:                        3.409   Durbin-Watson:                   1.295
# Prob(Omnibus):                  0.182   Jarque-Bera (JB):                1.949
# Skew:                          -0.548   Prob(JB):                        0.377
# Kurtosis:                       3.642   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Friendliness
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     2.254
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.125
# Time:                        15:54:37   Log-Likelihood:                -1.6925
# No. Observations:                  29   AIC:                             9.385
# Df Residuals:                      26   BIC:                             13.49
# Df Model:                           2
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.6123      0.114      5.382      0.000       0.389       0.835
# research_time_sum     -0.5885      0.289     -2.033      0.042      -1.156      -0.021
# research_click_sum     0.5625      0.301      1.871      0.061      -0.027       1.151
# ==============================================================================
# Omnibus:                        0.522   Durbin-Watson:                   1.783
# Prob(Omnibus):                  0.770   Jarque-Bera (JB):                0.452
# Skew:                          -0.277   Prob(JB):                        0.798
# Kurtosis:                       2.740   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Accomplishment
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.6311
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.540
# Time:                        15:54:37   Log-Likelihood:                -1.6654
# No. Observations:                  29   AIC:                             9.331
# Df Residuals:                      26   BIC:                             13.43
# Df Model:                           2
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.5449      0.101      5.414      0.000       0.348       0.742
# research_time_sum      0.4356      0.388      1.123      0.261      -0.324       1.196
# research_click_sum    -0.3911      0.427     -0.916      0.359      -1.228       0.445
# ==============================================================================
# Omnibus:                        1.036   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.596   Jarque-Bera (JB):                0.762
# Skew:                          -0.387   Prob(JB):                        0.683
# Kurtosis:                       2.824   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Control
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                    0.6236
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.544
# Time:                        15:54:37   Log-Likelihood:                -2.2123
# No. Observations:                  29   AIC:                             10.42
# Df Residuals:                      26   BIC:                             14.53
# Df Model:                           2
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.5174      0.130      3.986      0.000       0.263       0.772
# research_time_sum      0.4115      0.369      1.115      0.265      -0.312       1.135
# research_click_sum    -0.3217      0.397     -0.811      0.418      -1.099       0.456
# ==============================================================================
# Omnibus:                        3.697   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.158   Jarque-Bera (JB):                1.656
# Skew:                          -0.207   Prob(JB):                        0.437
# Kurtosis:                       1.905   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Reflection
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.057
# Method:                 Least Squares   F-statistic:                    0.2490
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.781
# Time:                        15:54:37   Log-Likelihood:                -2.3317
# No. Observations:                  29   AIC:                             10.66
# Df Residuals:                      26   BIC:                             14.77
# Df Model:                           2
# Covariance Type:                  HC3
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.5966      0.141      4.240      0.000       0.321       0.872
# research_time_sum     -0.2249      0.378     -0.595      0.552      -0.966       0.516
# research_click_sum     0.2277      0.336      0.677      0.498      -0.432       0.887
# ==============================================================================
# Omnibus:                        1.721   Durbin-Watson:                   2.159
# Prob(Omnibus):                  0.423   Jarque-Bera (JB):                1.524
# Skew:                          -0.522   Prob(JB):                        0.467
# Kurtosis:                       2.589   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
# from statsmodels.stats import linear_reset, het_breuschpagan, durbin_watson
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import statsmodels.api as sm

results_i = []
results_h3 = []

research

for kkk, j in enumerate(survey.columns):

    # Outlier Removal using Mahalanobis Distance
    data_mean = np.mean(design, axis=0)
    cov_matrix = np.cov(design.values.T)
    inv_cov_matrix = np.linalg.inv(cov_matrix)
    mahal_distances = design.apply(mahalanobis_distance, axis=1, args=(data_mean, inv_cov_matrix))
    threshold = np.percentile(mahal_distances, 97.5)
    design_filtered = design[mahal_distances < threshold]
    survey_tmp = pd.DataFrame(survey[j][design_filtered.index]).dropna()

    # Normalize Data
    min_max_scaler = MinMaxScaler()
    design_scaled = min_max_scaler.fit_transform(design_filtered)
    design_scaled = pd.DataFrame(design_scaled, columns=design_filtered.columns)
    survey_tmp_scaled = min_max_scaler.fit_transform(survey_tmp)

    # Model Fitting
    design_scaled = sm.add_constant(design_scaled[['design_time_sum', 'design_click_sum']])
    model_filtered = sm.OLS(survey_tmp_scaled, design_scaled)
    results_robust = model_filtered.fit(cov_type='HC3')

    # Append Results
    results_h3.append(results_robust)

    # Statistical Tests
    residuals = results_robust.resid
    def linearity_test():
        reset_test = linear_reset(results_robust, power=2, test_type='fitted')
        return reset_test.pvalue

    def normality_test():
        _, p_value = stats.normaltest(residuals)
        return p_value

    def homoscedasticity_test():
        _, p_value, _, _ = het_breuschpagan(residuals, results_robust.model.exog)
        return p_value

    def independence_test():
        return durbin_watson(residuals)

    # Filter based on p-values
    linearity_p_value = linearity_test()
    normality_p_value = normality_test()
    homoscedasticity_p_value = homoscedasticity_test()
    independence_statistic = independence_test()

    # Interpretation of Results
    if (
        linearity_p_value > 0.05 and
        normality_p_value > 0.05 and
        homoscedasticity_p_value > 0.05 and
        independence_statistic > 0.05
    ):
        print(f"Column: {j}")   
        print("\nInterpretation:")
        print("Linearity: Satisfied")
        print("Normality: Satisfied")
        print("Homoscedasticity: Satisfied")
        print("Independence: Satisfied")
        print("=" * 80)
        print(results_robust.summary())
# Out:
# Column: Effectiveness
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     1.129
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.339
# Time:                        15:54:38   Log-Likelihood:               -0.90917
# No. Observations:                  29   AIC:                             7.818
# Df Residuals:                      26   BIC:                             11.92
# Df Model:                           2
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.8003      0.105      7.608      0.000       0.594       1.006
# design_time_sum     -0.3630      0.245     -1.484      0.138      -0.842       0.116
# design_click_sum     0.1803      0.273      0.662      0.508      -0.354       0.714
# ==============================================================================
# Omnibus:                        4.809   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.090   Jarque-Bera (JB):                3.569
# Skew:                          -0.850   Prob(JB):                        0.168
# Kurtosis:                       3.247   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Efficiency
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                    0.7214
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.496
# Time:                        15:54:38   Log-Likelihood:                -1.8539
# No. Observations:                  29   AIC:                             9.708
# Df Residuals:                      26   BIC:                             13.81
# Df Model:                           2
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.7646      0.105      7.274      0.000       0.559       0.971
# design_time_sum     -0.3000      0.282     -1.063      0.288      -0.853       0.253
# design_click_sum     0.2710      0.243      1.113      0.266      -0.206       0.748
# ==============================================================================
# Omnibus:                        5.670   Durbin-Watson:                   1.383
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                4.049
# Skew:                          -0.868   Prob(JB):                        0.132
# Kurtosis:                       3.579   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Communication
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                 -0.033
# Method:                 Least Squares   F-statistic:                    0.2661
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.768
# Time:                        15:54:38   Log-Likelihood:                -2.1304
# No. Observations:                  29   AIC:                             10.26
# Df Residuals:                      26   BIC:                             14.36
# Df Model:                           2
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.4518      0.118      3.834      0.000       0.221       0.683
# design_time_sum     -0.1056      0.265     -0.399      0.690      -0.625       0.414
# design_click_sum     0.2652      0.364      0.728      0.467      -0.449       0.979
# ==============================================================================
# Omnibus:                        4.367   Durbin-Watson:                   1.576
# Prob(Omnibus):                  0.113   Jarque-Bera (JB):                1.763
# Skew:                          -0.195   Prob(JB):                        0.414
# Kurtosis:                       1.857   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Accomplishment
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.116
# Method:                 Least Squares   F-statistic:                     3.321
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):             0.0519
# Time:                        15:54:38   Log-Likelihood:                0.25380
# No. Observations:                  29   AIC:                             5.492
# Df Residuals:                      26   BIC:                             9.594
# Df Model:                           2
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.7910      0.093      8.551      0.000       0.610       0.972
# design_time_sum     -0.4172      0.198     -2.108      0.035      -0.805      -0.029
# design_click_sum    -0.0395      0.242     -0.163      0.870      -0.514       0.435
# ==============================================================================
# Omnibus:                        1.547   Durbin-Watson:                   1.662
# Prob(Omnibus):                  0.461   Jarque-Bera (JB):                1.035
# Skew:                          -0.462   Prob(JB):                        0.596
# Kurtosis:                       2.942   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Predictability
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                    0.8918
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.422
# Time:                        15:54:38   Log-Likelihood:                -5.7277
# No. Observations:                  29   AIC:                             17.46
# Df Residuals:                      26   BIC:                             21.56
# Df Model:                           2
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.7167      0.149      4.805      0.000       0.424       1.009
# design_time_sum     -0.3017      0.266     -1.136      0.256      -0.822       0.219
# design_click_sum    -0.1001      0.341     -0.294      0.769      -0.768       0.567
# ==============================================================================
# Omnibus:                        5.100   Durbin-Watson:                   1.536
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                1.899
# Skew:                          -0.203   Prob(JB):                        0.387
# Kurtosis:                       1.814   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Control
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.259
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     5.221
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):             0.0124
# Time:                        15:54:38   Log-Likelihood:                0.47059
# No. Observations:                  29   AIC:                             5.059
# Df Residuals:                      26   BIC:                             9.161
# Df Model:                           2
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.6982      0.113      6.190      0.000       0.477       0.919
# design_time_sum     -0.5464      0.176     -3.111      0.002      -0.891      -0.202
# design_click_sum     0.3841      0.225      1.703      0.089      -0.058       0.826
# ==============================================================================
# Omnibus:                        3.684   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.158   Jarque-Bera (JB):                1.673
# Skew:                          -0.220   Prob(JB):                        0.433
# Kurtosis:                       1.909   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Accuracy
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     3.770
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):             0.0365
# Time:                        15:54:38   Log-Likelihood:                 2.6973
# No. Observations:                  29   AIC:                            0.6055
# Df Residuals:                      26   BIC:                             4.707
# Df Model:                           2
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.6573      0.093      7.033      0.000       0.474       0.841
# design_time_sum     -0.4625      0.172     -2.696      0.007      -0.799      -0.126
# design_click_sum     0.1366      0.170      0.802      0.423      -0.197       0.471
# ==============================================================================
# Omnibus:                        4.001   Durbin-Watson:                   1.489
# Prob(Omnibus):                  0.135   Jarque-Bera (JB):                1.949
# Skew:                          -0.329   Prob(JB):                        0.377
# Kurtosis:                       1.914   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
# from statsmodels.stats import linear_reset, het_breuschpagan, durbin_watson
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import statsmodels.api as sm

results_i = []
results_h3 = []

research

for kkk, j in enumerate(survey.columns):

    # Outlier Removal using Mahalanobis Distance
    data_mean = np.mean(improvement, axis=0)
    cov_matrix = np.cov(improvement.values.T)
    inv_cov_matrix = np.linalg.inv(cov_matrix)
    mahal_distances = improvement.apply(mahalanobis_distance, axis=1, args=(data_mean, inv_cov_matrix))
    threshold = np.percentile(mahal_distances, 97.5)
    improvement_filtered = improvement[mahal_distances < threshold]
    survey_tmp = pd.DataFrame(survey[j][improvement_filtered.index]).dropna()

    # Normalize Data
    min_max_scaler = MinMaxScaler()
    improvement_scaled = min_max_scaler.fit_transform(improvement_filtered)
    improvement_scaled = pd.DataFrame(improvement_scaled, columns=improvement_filtered.columns)
    survey_tmp_scaled = min_max_scaler.fit_transform(survey_tmp)

    # Model Fitting
    improvement_scaled = sm.add_constant(improvement_scaled[['improvement_time_sum', 'improvement_click_sum']])
    model_filtered = sm.OLS(survey_tmp_scaled, improvement_scaled)
    results_robust = model_filtered.fit(cov_type='HC3')

    # Append Results
    results_h3.append(results_robust)

    # Statistical Tests
    residuals = results_robust.resid
    def linearity_test():
        reset_test = linear_reset(results_robust, power=2, test_type='fitted')
        return reset_test.pvalue

    def normality_test():
        _, p_value = stats.normaltest(residuals)
        return p_value

    def homoscedasticity_test():
        _, p_value, _, _ = het_breuschpagan(residuals, results_robust.model.exog)
        return p_value

    def independence_test():
        return durbin_watson(residuals)

    # Filter based on p-values
    linearity_p_value = linearity_test()
    normality_p_value = normality_test()
    homoscedasticity_p_value = homoscedasticity_test()
    independence_statistic = independence_test()

    # Interpretation of Results
    if (
        linearity_p_value > 0.05 and
        normality_p_value > 0.05 and
        homoscedasticity_p_value > 0.05 and
        independence_statistic > 0.05
    ):
        print(f"Column: {j}")   
        print("\nInterpretation:")
        print("Linearity: Satisfied")
        print("Normality: Satisfied")
        print("Homoscedasticity: Satisfied")
        print("Independence: Satisfied")
        print("=" * 80)
        print(results_robust.summary())
# Out:
# Column: Usefulness
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                    0.5738
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.570
# Time:                        15:54:39   Log-Likelihood:                -5.4194
# No. Observations:                  29   AIC:                             16.84
# Df Residuals:                      26   BIC:                             20.94
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.6154      0.099      6.246      0.000       0.422       0.808
# improvement_time_sum     -0.0925      0.457     -0.202      0.840      -0.988       0.803
# improvement_click_sum     0.2915      0.445      0.655      0.512      -0.580       1.163
# ==============================================================================
# Omnibus:                        4.642   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.098   Jarque-Bera (JB):                3.735
# Skew:                          -0.879   Prob(JB):                        0.154
# Kurtosis:                       3.004   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Ease
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                 -0.038
# Method:                 Least Squares   F-statistic:                    0.6569
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.527
# Time:                        15:54:39   Log-Likelihood:                0.62225
# No. Observations:                  29   AIC:                             4.756
# Df Residuals:                      26   BIC:                             8.857
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.6067      0.073      8.298      0.000       0.463       0.750
# improvement_time_sum      0.1000      0.473      0.211      0.833      -0.828       1.028
# improvement_click_sum     0.0834      0.497      0.168      0.867      -0.891       1.058
# ==============================================================================
# Omnibus:                        5.702   Durbin-Watson:                   1.575
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                4.543
# Skew:                          -0.964   Prob(JB):                        0.103
# Kurtosis:                       3.198   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Effectiveness
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     1.630
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.215
# Time:                        15:54:39   Log-Likelihood:               -0.40534
# No. Observations:                  29   AIC:                             6.811
# Df Residuals:                      26   BIC:                             10.91
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.5991      0.089      6.749      0.000       0.425       0.773
# improvement_time_sum     -0.1366      0.315     -0.434      0.665      -0.754       0.481
# improvement_click_sum     0.3811      0.286      1.334      0.182      -0.179       0.941
# ==============================================================================
# Omnibus:                        4.944   Durbin-Watson:                   1.794
# Prob(Omnibus):                  0.084   Jarque-Bera (JB):                3.713
# Skew:                          -0.868   Prob(JB):                        0.156
# Kurtosis:                       3.239   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Efficiency
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     3.687
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):             0.0389
# Time:                        15:54:39   Log-Likelihood:               -0.21262
# No. Observations:                  29   AIC:                             6.425
# Df Residuals:                      26   BIC:                             10.53
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.6301      0.094      6.673      0.000       0.445       0.815
# improvement_time_sum     -0.3621      0.273     -1.328      0.184      -0.896       0.172
# improvement_click_sum     0.5709      0.220      2.592      0.010       0.139       1.003
# ==============================================================================
# Omnibus:                        4.988   Durbin-Watson:                   1.570
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                3.451
# Skew:                          -0.806   Prob(JB):                        0.178
# Kurtosis:                       3.506   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Communication
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     2.910
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):             0.0724
# Time:                        15:54:39   Log-Likelihood:               -0.93554
# No. Observations:                  29   AIC:                             7.871
# Df Residuals:                      26   BIC:                             11.97
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.4695      0.097      4.833      0.000       0.279       0.660
# improvement_time_sum     -0.5477      0.500     -1.096      0.273      -1.527       0.432
# improvement_click_sum     0.5701      0.282      2.020      0.043       0.017       1.123
# ==============================================================================
# Omnibus:                        1.400   Durbin-Watson:                   1.703
# Prob(Omnibus):                  0.497   Jarque-Bera (JB):                0.981
# Skew:                           0.110   Prob(JB):                        0.612
# Kurtosis:                       2.126   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Friendliness
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                    0.8651
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.433
# Time:                        15:54:39   Log-Likelihood:                -2.3911
# No. Observations:                  29   AIC:                             10.78
# Df Residuals:                      26   BIC:                             14.88
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.6763      0.091      7.428      0.000       0.498       0.855
# improvement_time_sum      0.0637      0.368      0.173      0.862      -0.657       0.784
# improvement_click_sum    -0.2936      0.362     -0.811      0.417      -1.003       0.416
# ==============================================================================
# Omnibus:                        2.403   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.301   Jarque-Bera (JB):                2.041
# Skew:                          -0.628   Prob(JB):                        0.360
# Kurtosis:                       2.669   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Accomplishment
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.074
# Method:                 Least Squares   F-statistic:                   0.05251
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.949
# Time:                        15:54:39   Log-Likelihood:                -2.5759
# No. Observations:                  29   AIC:                             11.15
# Df Residuals:                      26   BIC:                             15.25
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.5624      0.086      6.571      0.000       0.395       0.730
# improvement_time_sum      0.0389      0.444      0.088      0.930      -0.831       0.909
# improvement_click_sum     0.0216      0.441      0.049      0.961      -0.843       0.886
# ==============================================================================
# Omnibus:                        1.460   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.482   Jarque-Bera (JB):                1.326
# Skew:                          -0.476   Prob(JB):                        0.515
# Kurtosis:                       2.565   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Control
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     1.139
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.336
# Time:                        15:54:39   Log-Likelihood:                -1.6793
# No. Observations:                  29   AIC:                             9.359
# Df Residuals:                      26   BIC:                             13.46
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.6611      0.090      7.382      0.000       0.486       0.837
# improvement_time_sum     -0.2892      0.724     -0.400      0.689      -1.707       1.129
# improvement_click_sum    -0.0404      0.734     -0.055      0.956      -1.479       1.398
# ==============================================================================
# Omnibus:                        3.426   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.180   Jarque-Bera (JB):                2.551
# Skew:                          -0.578   Prob(JB):                        0.279
# Kurtosis:                       2.119   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Accuracy
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                 -0.051
# Method:                 Least Squares   F-statistic:                    0.2101
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.812
# Time:                        15:54:39   Log-Likelihood:               -0.52472
# No. Observations:                  29   AIC:                             7.049
# Df Residuals:                      26   BIC:                             11.15
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.5417      0.097      5.564      0.000       0.351       0.733
# improvement_time_sum     -0.1328      0.587     -0.226      0.821      -1.283       1.018
# improvement_click_sum    -0.0297      0.357     -0.083      0.934      -0.729       0.670
# ==============================================================================
# Omnibus:                        1.723   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.423   Jarque-Bera (JB):                1.533
# Skew:                          -0.448   Prob(JB):                        0.465
# Kurtosis:                       2.317   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# Column: Reflection
#
# Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                    0.9269
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.408
# Time:                        15:54:39   Log-Likelihood:                -1.1729
# No. Observations:                  29   AIC:                             8.346
# Df Residuals:                      26   BIC:                             12.45
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.7012      0.078      9.017      0.000       0.549       0.854
# improvement_time_sum      0.0245      0.637      0.039      0.969      -1.224       1.273
# improvement_click_sum    -0.3256      0.598     -0.544      0.586      -1.499       0.847
# ==============================================================================
# Omnibus:                        2.299   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.317   Jarque-Bera (JB):                1.943
# Skew:                          -0.516   Prob(JB):                        0.378
# Kurtosis:                       2.264   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
results_i = []
results_h3 = []
for kkk,j in enumerate(df2.columns):
    df2 = df[col1]
    i2 = pd.DataFrame()
    i2['improvement_time_sum'] = improvement_time.sum(axis=1)
    i2['improvement_click_sum'] = improvement_click.sum(axis=1)

    i = pd.DataFrame(i2)
    i.columns = i2.columns

    data_mean = np.mean(i, axis=0)
    cov_matrix = np.cov(i.values.T)
    inv_cov_matrix = np.linalg.inv(cov_matrix)
    def mahalanobis_distance(row, mean, inv_cov_matrix):
        diff = row - mean
        return np.sqrt(diff.T @ inv_cov_matrix @ diff)
    
    mahal_distances = i.apply(mahalanobis_distance, axis=1, args=(data_mean, inv_cov_matrix))
    threshold = np.percentile(mahal_distances, 97.5)
    i = i[mahal_distances < threshold]
    df2_tmp = df2[j][i.index]
    df2_tmp = pd.DataFrame(df2_tmp).dropna(axis=0)

    min_max_scaler = MinMaxScaler()
    X_MinMax_train = min_max_scaler.fit_transform(i)
    i = pd.DataFrame(X_MinMax_train)
    df2_tmp = min_max_scaler.fit_transform(pd.DataFrame(df2_tmp))
    i.columns = i2.columns
    i = sm.add_constant(i[['improvement_time_sum', 'improvement_click_sum']])

    model_filtered = sm.OLS(df2_tmp, i)
    
    results = model_filtered.fit()
    results_robust = model_filtered.fit(cov_type='HC3')

    results_i.append(results)
    results_h3.append(results_robust)
    df2 = df[col1] # 점수

    # 1. 선형성 검정 (RESET 테스트 사용)
    def linearity_test():
        reset_test = linear_reset(results_robust, power=2, test_type='fitted')
        p_value = reset_test.pvalue
        print(f"RESET test p-value: {p_value}")
        return p_value
    
    # 2. 정규성 검정
    def normality_test():
        _, p_value = stats.normaltest(residuals)
        print(f"Normality test p-value: {p_value}")
        return p_value
    
    # 3. 등분산성 검정
    def homoscedasticity_test():
        _, p_value, _, _ = het_breuschpagan(residuals, results_robust.model.exog)
        print(f"Heteroscedasticity test p-value: {p_value}")
        return p_value
    
    # 4. 독립성 검정
    def independence_test():
        # dw_statistic = durbin_watson(residuals)
        dw_statistic=dg.acorr_breusch_godfrey(results_robust, nlags=3)[1]
        # dw_statistic = het_white(results_robust.resid, results_robust.model.exog)[1]
        print(f"Durbin-Watson statistic: {dw_statistic}")
        return dw_statistic

    # print(results.summary())
    if any(ele <= 0.05 for ele in results_robust.pvalues[1:].values):   
        print(j)
        print(results_robust.summary())
        # if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
        print("J: "+j)
        print('KKK'+str(kkk))
    
            
        residuals = results_robust.resid
        fitted_values = results_robust.fittedvalues    
        # 테스트 실행
        print("1. Linearity Test")
        linearity_p_value = linearity_test()
        
        print("\n2. Normality Test")
        normality_p_value = normality_test()
        
        print("\n3. Homoscedasticity Test")
        homoscedasticity_p_value = homoscedasticity_test()
        
        print("\n4. Independence Test")
        dw_statistic = independence_test()
        if linearity_p_value > 0.05 and normality_p_value > 0.05 and homoscedasticity_p_value > 0.05 and dw_statistic > 0.05:
            # 결과 해석
            print("\nResults Interpretation:")
            print(f"Linearity: {'Satisfied' if linearity_p_value > 0.05 else 'Not satisfied'}")
            print(f"Normality: {'Satisfied' if normality_p_value > 0.05 else 'Not satisfied'}")
            print(f"Homoscedasticity: {'Satisfied' if homoscedasticity_p_value > 0.05 else 'Not satisfied'}")
            # print(f"Independence: {'Satisfied' if 1.5 < dw_statistic < 2.5 else 'Not satisfied'}")
            print(f"Independence: {'Satisfied' if dw_statistic > 0.05 else 'Not satisfied'}")
        
        
            print('========================================================================')
# Out:
# 웹이 디자인 업무/공부 효율성에 도움을 줄 수 있다고 생각하나요?
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     3.687
# Date:                Tue, 12 Nov 2024   Prob (F-statistic):             0.0389
# Time:                        16:49:07   Log-Likelihood:               -0.21262
# No. Observations:                  29   AIC:                             6.425
# Df Residuals:                      26   BIC:                             10.53
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.6301      0.094      6.673      0.000       0.445       0.815
# improvement_time_sum     -0.3621      0.273     -1.328      0.184      -0.896       0.172
# improvement_click_sum     0.5709      0.220      2.592      0.010       0.139       1.003
# ==============================================================================
# Omnibus:                        4.988   Durbin-Watson:                   1.570
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                3.451
# Skew:                          -0.806   Prob(JB):                        0.178
# Kurtosis:                       3.506   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# J: 웹이 디자인 업무/공부 효율성에 도움을 줄 수 있다고 생각하나요?
# KKK4
# 1. Linearity Test
# RESET test p-value: 0.8254893386393582
#
# 2. Normality Test
# Normality test p-value: 0.08258321763096498
#
# 3. Homoscedasticity Test
# Heteroscedasticity test p-value: 0.06658602315133501
#
# 4. Independence Test
# Durbin-Watson statistic: 0.6755951795630408
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ========================================================================
# 웹과 소통이 잘 된다고 생각하나요?
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     2.910
# Date:                Tue, 12 Nov 2024   Prob (F-statistic):             0.0724
# Time:                        16:49:07   Log-Likelihood:               -0.93554
# No. Observations:                  29   AIC:                             7.871
# Df Residuals:                      26   BIC:                             11.97
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.4695      0.097      4.833      0.000       0.279       0.660
# improvement_time_sum     -0.5477      0.500     -1.096      0.273      -1.527       0.432
# improvement_click_sum     0.5701      0.282      2.020      0.043       0.017       1.123
# ==============================================================================
# Omnibus:                        1.400   Durbin-Watson:                   1.703
# Prob(Omnibus):                  0.497   Jarque-Bera (JB):                0.981
# Skew:                           0.110   Prob(JB):                        0.612
# Kurtosis:                       2.126   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# J: 웹과 소통이 잘 된다고 생각하나요?
# KKK6
# 1. Linearity Test
# RESET test p-value: 0.7434219842463279
#
# 2. Normality Test
# Normality test p-value: 0.49654365077535445
#
# 3. Homoscedasticity Test
# Heteroscedasticity test p-value: 0.13928432085516582
#
# 4. Independence Test
# Durbin-Watson statistic: 0.22413980867527117
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ========================================================================
# 웹의 UI가 일관성이 있다고 생각하나요?
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     2.188
# Date:                Tue, 12 Nov 2024   Prob (F-statistic):              0.132
# Time:                        16:49:07   Log-Likelihood:                -3.3386
# No. Observations:                  29   AIC:                             12.68
# Df Residuals:                      26   BIC:                             16.78
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.5862      0.094      6.265      0.000       0.403       0.770
# improvement_time_sum     -0.4723      0.393     -1.203      0.229      -1.242       0.297
# improvement_click_sum     0.5266      0.269      1.961      0.050       0.000       1.053
# ==============================================================================
# Omnibus:                        2.280   Durbin-Watson:                   2.471
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                1.763
# Skew:                          -0.598   Prob(JB):                        0.414
# Kurtosis:                       2.837   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# J: 웹의 UI가 일관성이 있다고 생각하나요?
# KKK8
# 1. Linearity Test
# RESET test p-value: 0.9068622478585966
#
# 2. Normality Test
# Normality test p-value: 0.31982045856542257
#
# 3. Homoscedasticity Test
# Heteroscedasticity test p-value: 0.30812943891191225
#
# 4. Independence Test
# Durbin-Watson statistic: 0.5195272172567209
#
# Results Interpretation:
# Linearity: Satisfied
# Normality: Satisfied
# Homoscedasticity: Satisfied
# Independence: Satisfied
# ========================================================================
# stress
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     6.281
# Date:                Tue, 12 Nov 2024   Prob (F-statistic):            0.00595
# Time:                        16:49:07   Log-Likelihood:                -5.5614
# No. Observations:                  29   AIC:                             17.12
# Df Residuals:                      26   BIC:                             21.22
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.1214      0.064      1.895      0.058      -0.004       0.247
# improvement_time_sum     -0.6380      0.292     -2.187      0.029      -1.210      -0.066
# improvement_click_sum     0.7995      0.240      3.334      0.001       0.330       1.270
# ==============================================================================
# Omnibus:                       18.318   Durbin-Watson:                   2.360
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.169
# Skew:                           1.741   Prob(JB):                     2.53e-05
# Kurtosis:                       5.323   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# J: stress
# KKK24
# 1. Linearity Test
# RESET test p-value: 0.7250584651248935
#
# 2. Normality Test
# Normality test p-value: 0.0001052584668291335
#
# 3. Homoscedasticity Test
# Heteroscedasticity test p-value: 0.8813625773945408
#
# 4. Independence Test
# Durbin-Watson statistic: 0.42566170733595643
